# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

# %%
df = pd.read_excel('Data for Case Study MT Data Analyst - NYL 2023-Copy1.xlsx')

df.head()
# Out:
#    Month  Year   SKU_ID SKU_Name         Sales    Stores  Transactions  \
# 0      1  2017  2023001  Wafer 1  1.298625e+07  24625.05     960240.00
# 1      2  2017  2023001  Wafer 1  1.232177e+07  25927.35     979057.50
# 2      3  2017  2023001  Wafer 1  1.265861e+07  27470.40    1116885.00
# 3      4  2017  2023001  Wafer 1  1.234409e+07  27051.90    1014221.25
# 4      5  2017  2023001  Wafer 1  1.210306e+07  27035.10    1021713.75
#
#    Salesman  Competitor_Sales  Temperature
# 0         0          0.000000        26.09
# 1         0     306335.491071        26.05
# 2         0     312790.178571        26.00
# 3         0     329385.535714        26.23
# 4         0     325542.857143        26.20

# %%
data = df.copy()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Month             186 non-null    int64
#  1   Year              186 non-null    int64
#  2   SKU_ID            186 non-null    int64
#  3   SKU_Name          186 non-null    object
#  4   Sales             186 non-null    float64
#  5   Stores            186 non-null    float64
#  6   Transactions      186 non-null    float64
#  7   Salesman          186 non-null    int64
#  8   Competitor_Sales  186 non-null    float64
#  9   Temperature       146 non-null    float64
# dtypes: float64(5), int64(4), object(1)
# memory usage: 14.7+ KB

# %%
data['Date'] = pd.to_datetime(data['Month'].astype(str) +'-'+ data['Year'].astype(str))
# Out:
# C:\Users\putra\AppData\Local\Temp\ipykernel_11728\3103813291.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Date'] = pd.to_datetime(data['Month'].astype(str) +'-'+ data['Year'].astype(str))

# %%
data.describe()
# Out:
#             Month        Year        SKU_ID         Sales        Stores  \
# count  186.000000   186.00000  1.860000e+02  1.860000e+02    186.000000
# mean     6.483871  2019.83871  2.023002e+06  1.190111e+07  39242.958065
# min      1.000000  2017.00000  2.023001e+06  2.513203e+04    889.200000
# 25%      3.000000  2018.00000  2.023001e+06  8.868497e+06  28911.487500
# 50%      6.500000  2020.00000  2.023002e+06  1.175635e+07  36067.800000
# 75%     10.000000  2021.00000  2.023002e+06  1.447175e+07  51192.300000
# max     12.000000  2023.00000  2.023003e+06  2.765255e+07  64594.650000
# std      3.524778     1.71032  7.610276e-01  6.029564e+06  13600.889467
#
#        Transactions    Salesman  Competitor_Sales  Temperature  \
# count  1.860000e+02  186.000000        186.000000   146.000000
# mean   1.363650e+06   19.344086     328796.070709    26.266849
# min    2.235000e+04    0.000000          0.000000    25.510000
# 25%    9.790153e+05   18.000000     297224.497768    25.920000
# 50%    1.321646e+06   21.000000     338743.325893    26.190000
# 75%    1.755997e+06   24.750000     404789.363839    26.470000
# max    2.414059e+06   38.000000     705910.178571    27.500000
# std    4.951776e+05    8.624283     158979.634852     0.475925
#
#                                 Date
# count                            186
# mean   2020-04-17 17:17:25.161290240
# min              2017-01-01 00:00:00
# 25%              2018-12-01 00:00:00
# 50%              2020-06-16 00:00:00
# 75%              2021-10-01 00:00:00
# max              2023-01-01 00:00:00
# std                              NaN

# %%
data[data['Transactions'] == data['Transactions'].max()]
# Out:
#     Month  Year   SKU_ID SKU_Name         Sales   Stores  Transactions  \
# 58     11  2021  2023001  Wafer 1  2.350062e+07  63585.0    2414058.75
#
#     Salesman  Competitor_Sales  Temperature       Date
# 58        26     556996.741071        26.14 2021-11-01

# %%
data[data['Sales'] == data['Sales'].min()]
# Out:
#      Month  Year   SKU_ID SKU_Name         Sales  Stores  Transactions  \
# 146     10  2019  2023003  Wafer 3  25132.033203   889.2       22350.0
#
#      Salesman  Competitor_Sales  Temperature       Date
# 146        21         2269.6875          NaN 2019-10-01

# %%
plt.figure(figsize=(20,15))

for i in data.describe().columns:
    fig, (ax1, ax2) = plt.subplots(2, sharex = True, figsize = (5,2.5))
    ax1.set_title(f"Distribution of {i}", color = "black")
    sns.boxplot(x = df[i], ax = ax1)
    ax1.set_xlabel ("")
    sns.histplot(data = df, x=i, ax = ax2, stat = "count", kde=True, bins=30)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\.conda\envs\belajar_api\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\.conda\envs\belajar_api\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\.conda\envs\belajar_api\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 6
#       4 fig, (ax1, ax2) = plt.subplots(2, sharex = True, figsize = (5,2.5))
#       5 ax1.set_title(f"Distribution of {i}", color = "black")
# ----> 6 sns.boxplot(x = df[i], ax = ax1)
#       7 ax1.set_xlabel ("")
#       8 sns.histplot(data = df, x=i, ax = ax2, stat = "count", kde=True, bins=30)
#
# File ~\.conda\envs\belajar_api\lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\.conda\envs\belajar_api\lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Date'

# %%
numerical_features = data.describe().columns

plt.figure(figsize=(10,8))

mask = np.triu(data[numerical_features].corr(method='spearman'))

sns.heatmap(data=data[numerical_features].corr(method='spearman'), annot=True, fmt='.3f', cmap='coolwarm', center=0, mask=mask)
plt.title('Korelasi Antara Setiap Variabel Numerik')
# Out:
# Text(0.5, 1.0, 'Korelasi Antara Setiap Variabel Numerik')

# %%
def ylabel(x, pos):
    return f'{x*1e-6:1.1f} Juta'

# %%
dat1 = data.groupby(['Date'], as_index=False)['Sales'].sum()

fig, ax = plt.subplots()
ax = sns.lineplot(dat1, x='Date', y='Sales')
ax.set_title('Tren Penjualan Produk Sejak 2017', fontsize=16)
ax.set_xlabel('Tanggal')
ax.set_ylabel('Total Penjualan')
ax.yaxis.set_major_formatter(ylabel)
ax.grid(visible=True, alpha=0.3)
plt.show()

# %%
fig, ax = plt.subplots()
ax = sns.lineplot(dat1[dat1['Date'].dt.year > 2021], x='Date',y="Sales")
ax.set_title('Tren Penjualan Produk dalam Setahun Terakhir', fontsize=16)
ax.set_xlabel('Tanggal')
ax.set_ylabel('Total Penjualan')
ax.yaxis.set_major_formatter(ylabel)
ax.grid(visible=True, alpha=0.3)
plt.show()

# %%
dat1.sort_values(by=['Sales'], ascending=False)
# Out:
#          Date         Sales
# 67 2022-08-01  5.387059e+07
# 68 2022-09-01  5.385634e+07
# 69 2022-10-01  5.376919e+07
# 71 2022-12-01  5.125490e+07
# 70 2022-11-01  4.891031e+07
# ..        ...           ...
# 21 2018-10-01  1.870333e+07
# 28 2019-05-01  1.621782e+07
# 5  2017-06-01  1.534469e+07
# 17 2018-06-01  1.451030e+07
# 29 2019-06-01  1.355556e+07
#
# [73 rows x 2 columns]

# %%
dat1['Sales'].pct_change(periods=len(dat1)-1)*100
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#         ...
# 68          NaN
# 69          NaN
# 70          NaN
# 71          NaN
# 72    68.835925
# Name: Sales, Length: 73, dtype: float64

# %%
dat2 = data.groupby(['SKU_Name'], as_index=False)['Sales'].sum()

fig, ax = plt.subplots()
sns.barplot(dat2, x='SKU_Name', y='Sales')
ax.set_title('Total Penjualan Setiap Produk', fontsize=16)
ax.set_xlabel('Nama Produk')
ax.set_ylabel('Total Penjualan')
ax.yaxis.set_major_formatter(ylabel)
ax.grid(visible=True, alpha=0.3)
plt.show()

# %%
dat3 = data.groupby(['Year', 'SKU_Name'], as_index=False)['Sales'].sum()

fig, ax = plt.subplots()
sns.barplot(dat3, x="Year", y="Sales", hue="SKU_Name")
ax.set_title('Total Penjualan Setiap Produk dalam Setiap Tahunnya', fontsize=16)
ax.set_xlabel('Tahun')
ax.set_ylabel('Total Penjualan')
ax.yaxis.set_major_formatter(ylabel)
ax.legend(title='Nama Produk')
ax.grid(visible=True, alpha=0.3)
plt.show()

# %%
dat4 = data.groupby(['Date', 'SKU_Name'], as_index=False)['Sales'].sum()

fig, ax = plt.subplots()
ax = sns.lineplot(dat4, x='Date', y='Sales', hue='SKU_Name')
ax.set_title('Tren Penjualan Setiap Produk Sejak Diluncurkan', fontsize=16)
ax.set_xlabel('Tanggal')
ax.set_ylabel('Total Penjualan')
ax.yaxis.set_major_formatter(ylabel)
ax.legend(title='Nama Produk')
ax.grid(visible=True, alpha=0.3)
plt.show()

# %%
dat5 =  data.groupby(['Year'], as_index=False)[['Sales','Competitor_Sales']].sum()

fig, ax = plt.subplots(figsize=(7,5))
sns.barplot(dat5.melt(['Year']), x='Year', y='value', hue='variable')
ax.set_title('Perbandingan Penjualan Produk dengan Kompetitor', fontsize=16)
ax.set_xlabel('Tahun')
ax.set_ylabel('Total Penjualan')
ax.yaxis.set_major_formatter(ylabel)
ax.legend(title=False)
plt.show()

# %%
dat6 =  data.groupby(['Date'], as_index=False)['Competitor_Sales'].sum()

fig, ax = plt.subplots(figsize=(7,5))
sns.lineplot(dat6, x='Date', y='Competitor_Sales')
ax.set_title('Perbandingan Penjualan Produk dengan Kompetitor', fontsize=16)
ax.set_xlabel('Tahun')
ax.set_ylabel('Total Penjualan')
ax.yaxis.set_major_formatter(ylabel)
ax.grid(visible=True, alpha=0.3)
plt.show()

# %%
dat6['Competitor_Sales'].pct_change(periods=len(dat1)-1)*10
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#         ...
# 68         NaN
# 69         NaN
# 70         NaN
# 71         NaN
# 72    19.65973
# Name: Competitor_Sales, Length: 73, dtype: float64

# %%
dat7 = data.groupby(['Date','SKU_Name'], as_index=False)[['Sales','Competitor_Sales']].sum()

fig, axes = plt.subplots(3,1, figsize=(14,7))
for i, j in zip(dat7['SKU_Name'].unique(), axes.flatten()):
    ax = sns.lineplot(dat7[dat7['SKU_Name'] == i].melt(['Date','SKU_Name']), x='Date', y='value', hue='variable', ax=j)
    ax.set_xlabel('Tanggal')
    ax.set_ylabel('Total Penjualan')
    ax.yaxis.set_major_formatter(ylabel)
    ax.get_legend().remove()
plt.suptitle('Perbandingan Performa Penjualan Setiap Produk dengan Kompetitor')
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', ncol=2, bbox_to_anchor=(, 0.5))
plt.show()

# %%
fig, ax =plt.subplots()
ax = sns.scatterplot(data, x='Sales', y='Transactions', hue='SKU_Name')
plt.show()
